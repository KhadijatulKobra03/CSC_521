# %% [markdown]
# <a href="https://colab.research.google.com/github/KhadijatulKobra03/CSC_521/blob/main/W5_PA_CA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Sorts array a[0..n-1] using Bogo sort
def bogoSort(a):
        n = len(a)
        while not is_sorted(a):
                shuffle(a)
                print("Current array state:",a)

# To check if array is sorted or not
def is_sorted(a):
        n = len(a)
        for i in range(0, n-1):
                if (a[i] > a[i+1] ):
                        return False
        return True

# To generate permutation of the array
def shuffle(a):
        n = len(a)
        for i in range (n):
                r = random.randint(0,n-1)
                a[i], a[r] = a[r], a[i]

# Driver code to test above

a = [3, 2, 4, 1, 0, 5]
bogoSort(a)
print("==================")
print("Sorted array :")
print (" ".join(str(x)for x in a))
print ("=================")
# Out:
# Current array state: [4, 0, 2, 3, 5, 1]
# Current array state: [2, 4, 3, 0, 1, 5]
# Current array state: [0, 3, 5, 2, 4, 1]
# Current array state: [4, 2, 5, 1, 3, 0]
# Current array state: [3, 2, 4, 0, 5, 1]
# Current array state: [3, 1, 4, 5, 2, 0]
# Current array state: [2, 5, 0, 4, 1, 3]
# Current array state: [3, 0, 2, 5, 1, 4]
# Current array state: [1, 3, 4, 2, 0, 5]
# Current array state: [2, 4, 3, 0, 1, 5]
# Current array state: [2, 4, 1, 3, 0, 5]
# Current array state: [4, 2, 1, 5, 0, 3]
# Current array state: [2, 1, 4, 5, 0, 3]
# Current array state: [3, 2, 1, 0, 5, 4]
# Current array state: [2, 0, 1, 5, 3, 4]
# Current array state: [3, 5, 2, 0, 4, 1]
# Current array state: [1, 2, 4, 3, 0, 5]
# Current array state: [2, 5, 4, 3, 1, 0]
# Current array state: [5, 2, 1, 0, 3, 4]
# Current array state: [5, 0, 3, 1, 4, 2]
# Current array state: [0, 5, 1, 3, 2, 4]
# Current array state: [2, 5, 0, 1, 4, 3]
# Current array state: [4, 3, 2, 1, 5, 0]
# ...

# %%
def bubbleSort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1]=arr[j+1], arr[j]
                print("Step:", arr)
                print("After pass", i+1, ":", arr)
                print("")
                return arr
#Driver code to test above
arr= [64, 35, 29, 20, 9,90,11]
print("Original array:", arr)
sorted_arr = bubbleSort(arr)
print("Sorted array:", sorted_arr)
# Out:
# Original array: [64, 35, 29, 20, 9, 90, 11]
# Step: [35, 64, 29, 20, 9, 90, 11]
# After pass 1 : [35, 64, 29, 20, 9, 90, 11]
#
# Sorted array: [35, 64, 29, 20, 9, 90, 11]

# %%
def selectionSort(arr):
  n = len(arr)
  for i in range(n):
    min_index = i
    for j in range(i+1, n):
      if arr[j] < arr[min_index]:
        min_index = j

# Swap the found minimum element with the first element of the unsorted part
        arr[i], arr[min_index] = arr[min_index], arr[i]
        print("After iteration", i+1, ":", arr)
        return arr
#Driver code to test above
arr = [64, 35, 29, 20, 9,90,11]
print("Original array:", arr)
sorted_arr = selectionSort(arr)
print("Sorted array:", sorted_arr)
# Out:
# Original array: [64, 35, 29, 20, 9, 90, 11]
# After iteration 1 : [35, 64, 29, 20, 9, 90, 11]
# Sorted array: [35, 64, 29, 20, 9, 90, 11]
